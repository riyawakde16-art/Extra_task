# %% [markdown]
# <a href="https://colab.research.google.com/github/riyawakde16-art/Extra_task/blob/main/Special_task(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c94f1c55-12b8-4687-9496-0d54bbf19b21" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c94f1c55-12b8-4687-9496-0d54bbf19b21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("/content/Employee.csv")
print(df)
# Out:
#      emp_id employee_name  gender  age department           job_role  \
# 0         1  Anjali Mehta    Male   45         HR  Software Engineer
# 1         2   Neha Kapoor  Female   50  Marketing  Marketing Analyst
# 2         3    Karan Shah    Male   32         IT       Data Analyst
# 3         4   Rahul Patil    Male   37  Marketing       Data Analyst
# 4         5   Riya Sharma    Male   29      Sales  Software Engineer
# ..      ...           ...     ...  ...        ...                ...
# 995     996   Arjun Singh  Female   45      Sales  Marketing Analyst
# 996     997    Karan Shah  Female   52  Marketing  Marketing Analyst
# 997     998  Rajesh Gupta  Female   22    Finance       Data Analyst
# 998     999   Riya Sharma    Male   39         HR  Software Engineer
# 999    1000   Rahul Patil    Male   31  Marketing    Sales Executive
#
#                         email  phone_number       city        state  ...  \
# ...

# %%
df.head()
# Out:
#    emp_id employee_name  gender  age department           job_role  \
# 0       1  Anjali Mehta    Male   45         HR  Software Engineer
# 1       2   Neha Kapoor  Female   50  Marketing  Marketing Analyst
# 2       3    Karan Shah    Male   32         IT       Data Analyst
# 3       4   Rahul Patil    Male   37  Marketing       Data Analyst
# 4       5   Riya Sharma    Male   29      Sales  Software Engineer
#
#                       email  phone_number       city        state  ...  \
# 0  anjali.mehta@company.com    8767705334  Hyderabad    Karnataka  ...
# 1   neha.kapoor@company.com    7350849248  Bangalore  Maharashtra  ...
# 2    karan.shah@company.com    7160671832  Bangalore    Karnataka  ...
# 3   rahul.patil@company.com    7284761706     Mumbai  Maharashtra  ...
# 4   riya.sharma@company.com    9195229456  Hyderabad    Telangana  ...
#
#   reward_points  employee_of_month_count  device_allocated  system_os  \
# ...

# %%
df.shape
# Out:
# (1000, 79)

# %%
df.columns
# Out:
# Index(['emp_id', 'employee_name', 'gender', 'age', 'department', 'job_role',
#        'email', 'phone_number', 'city', 'state', 'country', 'salary', 'bonus',
#        'experience_years', 'joining_date', 'employment_type', 'shift',
#        'work_mode', 'manager_name', 'team_name', 'performance_rating',
#        'leaves_taken', 'sick_leaves', 'casual_leaves', 'project_count',
#        'training_hours', 'promotion_status', 'last_promotion_year',
#        'appraisal_score', 'attendance_percentage', 'overtime_hours',
#        'education', 'university', 'graduation_year', 'marital_status',
#        'blood_group', 'nationality', 'bank_name', 'account_number',
#        'ifsc_code', 'emergency_contact_name', 'emergency_contact_number',
#        'skills', 'certifications', 'languages_known', 'current_project',
#        'project_deadline', 'project_status', 'previous_company',
#        'notice_period', 'work_location', 'desk_number', 'employee_type',
# ...

# %%
df.dtypes
# Out:
# emp_id                  int64
# employee_name          object
# gender                 object
# age                     int64
# department             object
#                         ...
# shift_allowance         int64
# food_allowance          int64
# transport_allowance     int64
# bonus_eligibility      object
# retirement_plan        object
# Length: 79, dtype: object

# %%
df.isnull().sum()
# Out:
# emp_id                 0
# employee_name          0
# gender                 0
# age                    0
# department             0
#                       ..
# shift_allowance        0
# food_allowance         0
# transport_allowance    0
# bonus_eligibility      0
# retirement_plan        0
# Length: 79, dtype: int64

# %%
df.describe()
# Out:
#             emp_id          age  phone_number         salary        bonus  \
# count  1000.000000  1000.000000  1.000000e+03    1000.000000   1000.00000
# mean    500.500000    40.513000  8.467767e+09   74778.680830  12449.28025
# std     288.819436    11.295549  8.584466e+08   26226.870149   4348.94860
# min       1.000000    21.000000  7.008096e+09   30012.900000   5001.90000
# 25%     250.750000    31.000000  7.751988e+09   51762.727500   8594.49000
# 50%     500.500000    41.000000  8.406426e+09   74776.765000  12694.18000
# 75%     750.250000    50.000000  9.182150e+09   98231.090000  16125.45250
# max    1000.000000    60.000000  9.997849e+09  119968.770000  19950.58000
#
#        experience_years  performance_rating  leaves_taken  sick_leaves  \
# count        1000.00000         1000.000000   1000.000000  1000.000000
# mean            5.51800            3.985140     14.971000     5.105000
# std             2.89967            0.578064      8.906823     3.213768
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
num_data = df[[ 'age', 'salary', 'bonus']]
corr = num_data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap of Numerical Variables")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x='department', y='salary', hue='gender', data=df, palette='Set2')
plt.title('Insurance Salary by Bonus and Gender')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.legend(title='Gender')
plt.show()

# %%
import seaborn as sns
sns.histplot(df['age'])
plt.show()

# %%
import matplotlib.pyplot as plt
gender_counts=df['gender'].value_counts()
plt.figure()
plt.pie(gender_counts,labels=gender_counts.index,autopct="%1.1f%%")
plt.title("Gender Type Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["age"], df["salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()
